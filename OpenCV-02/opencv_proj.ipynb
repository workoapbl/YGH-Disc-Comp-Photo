# %% [markdown]
# # Project: Use OpenCV, Numpy, & Matplotlib to edit an image you took
#
# Steps:
# 1. Load an image
# 2. Make at least **2** types of edits. Choose 2 from the following: brightness/contrast, tinting/greyscale, cropping, pixel edits.
# 3. Save the image and display it

# %%
# Imports
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load your image
image = # YOUR CODE HERE

# %%
# Edit 1

# %%
# Edit 2

# %%
# Save your image

# %%
# Display your image
